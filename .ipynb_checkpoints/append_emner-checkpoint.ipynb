# %%
import pandas as pd
import nltk

# %%
df = pd.read_csv('/home/polichinel/Dropbox/KU/7.semester/SDS/python_n_data/sds_eks/13300.csv')

# %%
emner = ['international politik','økonomi & velfærd','ret & politi','familie & børn','uddannelse','kultur & religion','køn & ligestilling','medier, kommunikation & it','miljø & klima','flygtninge & intengrationspolitik','andet','ignore']

# %%
for i in emner:
    df[i] = pd.Series()

# %%
df
# Out:
#        Unnamed: 0                                              links  \
# 0               0              /debat/leder/2016/06/stupide-kongehus
# 1               1       /debat/2016/06/public-service-public-service
# 2               2  /debat/2016/06/roed-bloks-fald-venstrefloejens...
# 3               3        /debat/leder/2016/06/faa-styr-paa-bistanden
# 4               4                      /debat/2016/06/laeserbreve-15
# 5               5          /debat/leder/2016/06/ting-opleves-kroppen
# 6               6  /debat/2016/06/ogsaa-hollaenderne-tabt-troen-p...
# 7               7             /debat/2016/06/uvirkelighedens-politik
# 8               8                             /debat/2016/06/folk-16
# 9               9                             /debat/2016/06/folk-15
# 10             10                      /debat/2016/06/laeserbreve-14
# 11             11  /debat/leder/2016/06/bryd-ensretningen-paa-oek...
# 12             12     /debat/2016/06/afghanistan-kraever-stadig-ofre
# ...
